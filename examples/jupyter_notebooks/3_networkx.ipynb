# %% [markdown]
# # Introduction to FBL: Part 3: NetworkX
#
# For using both FFBO and FBL efficiently and correctly, you should learn
# to use NetworkX, a graph library for Python.
# You can access the documentation here:
# https://networkx.github.io/documentation/stable/
#
#
#
# Let us start with a basic query and get the connectivity dendrogram:

# %%
nm[0].executeNLPquery('show GABAergic neurons in the ellipsoid body')
nm[0].getConnectivityDendrogram()
# Out:
# [FFBOLab Client NLP 2019-02-01 20:26:32] NLP successfully parsed query.
# [FFBOLab Client NLP 2019-02-01 20:26:33] Received a message.
# [FFBOLab Client NLP 2019-02-01 20:26:33] Received a command.
# [FFBOLab Client NLP 2019-02-01 20:26:34] Received data.
# [FFBOLab Client NLP 2019-02-01 20:26:34] Received data.
# [FFBOLab Client NLP 2019-02-01 20:26:34] Received a message.
# [FFBOLab Client NLP 2019-02-01 20:26:34] Received data.
# ['EB']
# [FFBOLab Client NLP 2019-02-01 20:26:38] Received a message.
# [FFBOLab Client NLP 2019-02-01 20:26:38] Received data.

# %% [markdown]
# We can now access the circuit graph as follows:

# %%
circuit_graph = nm[0].C.G

# %% [markdown]
# We can for example look at a list of nodes:

# %%
print(circuit_graph.nodes(data=True))
# Out:
# [('uid0', {'class': 'MorrisLecar', 'name': 'Gad1-F-300341', 'V1': -20.0, 'V2': 50.0, 'V3': -40.0, 'V4': 20.0, 'phi': 0.4, 'offset': 0.0, 'V_L': -40.0, 'V_Ca': 120.0, 'V_K': -80.0, 'g_L': 3.0, 'g_Ca': 4.0, 'g_K': 16.0, 'initV': -46.08, 'initn': 0.3525}), ('uid1', {'class': 'MorrisLecar', 'name': 'Gad1-F-500284', 'V1': -20.0, 'V2': 50.0, 'V3': -40.0, 'V4': 20.0, 'phi': 0.4, 'offset': 0.0, 'V_L': -40.0, 'V_Ca': 120.0, 'V_K': -80.0, 'g_L': 3.0, 'g_Ca': 4.0, 'g_K': 16.0, 'initV': -46.08, 'initn': 0.3525}), ('uid2', {'class': 'MorrisLecar', 'name': 'Gad1-F-400328', 'V1': -20.0, 'V2': 50.0, 'V3': -40.0, 'V4': 20.0, 'phi': 0.4, 'offset': 0.0, 'V_L': -40.0, 'V_Ca': 120.0, 'V_K': -80.0, 'g_L': 3.0, 'g_Ca': 4.0, 'g_K': 16.0, 'initV': -46.08, 'initn': 0.3525}), ('uid3', {'class': 'MorrisLecar', 'name': 'Gad1-F-900073', 'V1': -20.0, 'V2': 50.0, 'V3': -40.0, 'V4': 20.0, 'phi': 0.4, 'offset': 0.0, 'V_L': -40.0, 'V_Ca': 120.0, 'V_K': -80.0, 'g_L': 3.0, 'g_Ca': 4.0, 'g_K': 16.0, 'initV': -46.08, 'initn': 0.3525}), ('uid4', {'class': 'MorrisLecar', 'name': 'Gad1-F-700047', 'V1': -20.0, 'V2': 50.0, 'V3': -40.0, 'V4': 20.0, 'phi': 0.4, 'offset': 0.0, 'V_L': -40.0, 'V_Ca': 120.0, 'V_K': -80.0, 'g_L': 3.0, 'g_Ca': 4.0, 'g_K': 16.0, 'initV': -46.08, 'initn': 0.3525}), ('uid5', {'class': 'MorrisLecar', 'name': 'Gad1-F-200171', 'V1': -20.0, 'V2': 50.0, 'V3': -40.0, 'V4': 20.0, 'phi': 0.4, 'offset': 0.0, 'V_L': -40.0, 'V_Ca': 120.0, 'V_K': -80.0, 'g_L': 3.0, 'g_Ca': 4.0, 'g_K': 16.0, 'initV': -46.08, 'initn': 0.3525}), ('uid6', {'class': 'MorrisLecar', 'name': 'Gad1-F-100200', 'V1': -20.0, 'V2': 50.0, 'V3': -40.0, 'V4': 20.0, 'phi': 0.4, 'offset': 0.0, 'V_L': -40.0, 'V_Ca': 120.0, 'V_K': -80.0, 'g_L': 3.0, 'g_Ca': 4.0, 'g_K': 16.0, 'initV': -46.08, 'initn': 0.3525}), ('uid7', {'class': 'MorrisLecar', 'name': 'Gad1-F-400135', 'V1': -20.0, 'V2': 50.0, 'V3': -40.0, 'V4': 20.0, 'phi': 0.4, 'offset': 0.0, 'V_L': -40.0, 'V_Ca': 120.0, 'V_K': -80.0, 'g_L': 3.0, 'g_Ca': 4.0, 'g_K': 16.0, 'initV': -46.08, 'initn': 0.3525}), ('uid8', {'class': 'MorrisLecar', 'name': 'Gad1-F-500156', 'V1': -20.0, 'V2': 50.0, 'V3': -40.0, 'V4': 20.0, 'phi': 0.4, 'offset': 0.0, 'V_L': -40.0, 'V_Ca': 120.0, 'V_K': -80.0, 'g_L': 3.0, 'g_Ca': 4.0, 'g_K': 16.0, 'initV': -46.08, 'initn': 0.3525}), ('uid9', {'class': 'MorrisLecar', 'name': 'Gad1-F-300071', 'V1': -20.0, 'V2': 50.0, 'V3': -40.0, 'V4': 20.0, 'phi': 0.4, 'offset': 0.0, 'V_L': -40.0, 'V_Ca': 120.0, 'V_K': -80.0, 'g_L': 3.0, 'g_Ca': 4.0, 'g_K': 16.0, 'initV': -46.08, 'initn': 0.3525}), ('uid10', {'class': 'MorrisLecar', 'name': 'Gad1-F-500106', 'V1': -20.0, 'V2': 50.0, 'V3': -40.0, 'V4': 20.0, 'phi': 0.4, 'offset': 0.0, 'V_L': -40.0, 'V_Ca': 120.0, 'V_K': -80.0, 'g_L': 3.0, 'g_Ca': 4.0, 'g_K': 16.0, 'initV': -46.08, 'initn': 0.3525}), ('uid11', {'class': 'MorrisLecar', 'name': 'Gad1-F-200210', 'V1': -20.0, 'V2': 50.0, 'V3': -40.0, 'V4': 20.0, 'phi': 0.4, 'offset': 0.0, 'V_L': -40.0, 'V_Ca': 120.0, 'V_K': -80.0, 'g_L': 3.0, 'g_Ca': 4.0, 'g_K': 16.0, 'initV': -46.08, 'initn': 0.3525}), ('uid12', {'class': 'MorrisLecar', 'name': 'Gad1-F-000089', 'V1': -20.0, 'V2': 50.0, 'V3': -40.0, 'V4': 20.0, 'phi': 0.4, 'offset': 0.0, 'V_L': -40.0, 'V_Ca': 120.0, 'V_K': -80.0, 'g_L': 3.0, 'g_Ca': 4.0, 'g_K': 16.0, 'initV': -46.08, 'initn': 0.3525}), ('uid13', {'class': 'MorrisLecar', 'name': 'Gad1-F-000050', 'V1': -20.0, 'V2': 50.0, 'V3': -40.0, 'V4': 20.0, 'phi': 0.4, 'offset': 0.0, 'V_L': -40.0, 'V_Ca': 120.0, 'V_K': -80.0, 'g_L': 3.0, 'g_Ca': 4.0, 'g_K': 16.0, 'initV': -46.08, 'initn': 0.3525}), ('uid14', {'class': 'MorrisLecar', 'name': 'Gad1-F-500127', 'V1': -20.0, 'V2': 50.0, 'V3': -40.0, 'V4': 20.0, 'phi': 0.4, 'offset': 0.0, 'V_L': -40.0, 'V_Ca': 120.0, 'V_K': -80.0, 'g_L': 3.0, 'g_Ca': 4.0, 'g_K': 16.0, 'initV': -46.08, 'initn': 0.3525}), ('uid15', {'class': 'MorrisLecar', 'name': 'Gad1-F-100385', 'V1': -20.0, 'V2': 50.0, 'V3': -40.0, 'V4': 20.0, 'phi': 0.4, 'offset': 0.0, 'V_L': -40.0, 'V_Ca': 120.0, 'V_K': -80.0, 'g_L': 3.0, 'g_Ca': ...

# %% [markdown]
# Or the synapses:

# %%
print(circuit_graph.edges(data=True))
# Out:
# [('uid1', 'uid609', {'delay': 0.0, 'tag': 0}), ('uid2', 'uid272', {'delay': 0.0, 'tag': 0}), ('uid2', 'uid273', {'delay': 0.0, 'tag': 0}), ('uid2', 'uid274', {'delay': 0.0, 'tag': 0}), ('uid2', 'uid275', {'delay': 0.0, 'tag': 0}), ('uid2', 'uid276', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid133', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid134', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid135', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid136', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid137', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid138', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid139', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid140', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid141', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid142', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid143', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid144', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid145', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid146', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid147', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid148', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid149', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid150', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid151', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid152', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid153', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid154', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid155', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid156', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid157', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid158', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid159', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid160', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid161', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid162', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid163', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid164', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid165', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid166', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid167', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid168', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid169', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid170', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid171', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid172', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid173', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid174', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid175', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid176', {'delay': 0.0, 'tag': 0}), ('uid3', 'uid177', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid30', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid31', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid32', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid33', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid34', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid35', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid36', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid37', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid38', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid39', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid40', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid41', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid42', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid43', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid44', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid45', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid46', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid47', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid48', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid49', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid50', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid51', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid52', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid53', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid54', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid55', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid56', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid57', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid58', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid59', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid60', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid61', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid62', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid63', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid64', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid65', {'delay': 0.0, 'tag': 0}), ('uid4', 'uid66', {'delay': 0.0,  ...

# %% [markdown]
# This circuit is automatically generated in a Neurokernel-executable format.
#
# For simulations, it is recommended that you start to look at Neurodriver at:
# https://github.com/neurokernel/neurodriver
