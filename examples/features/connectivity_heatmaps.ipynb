# %% [markdown]
# This demo shows two connectivity matrix visualization functions. Uses the Hemibrain dataset.

# %%
# %matplotlib inline
client = fbl.get_client()

# %%
_res = client.executeNLPquery('$VP3$')
# Out:
# [FBL NLP 2021-02-16 21:52:03,809] NLP successfully parsed query.

# %%
# %matplotlib inline
client.draw_adjacency_by_name(_res)

# %%
_res2 = client.executeNLPquery('color $VP3$ red')
# Out:
# [FBL NLP 2021-02-16 21:52:10,211] NLP successfully parsed query.

# %%
_res3 = client.executeNLPquery('color $TRN$ blue')
# Out:
# [FBL NLP 2021-02-16 21:52:11,672] NLP successfully parsed query.

# %%
# %matplotlib inline
client.draw_adjacency_with_colors(_res)
